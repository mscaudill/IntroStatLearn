# %% [markdown]
# # ISLR: Chapter 2 Exercise 9

# %% [markdown]
# ## Imports

# %%
# Perform all the necessary imports and set plot style
# %matplotlib inline

from matplotlib import pyplot as plt
import pandas as pd

plt.style.use('ggplot') # emulate R's ggplot package

# %%
Auto = pd.read_csv('../../Data_sets/Auto.csv',na_values='?')

# %%
Auto.head()
# Out:
#    mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0   18          8           307         130    3504          12.0    70
# 1   15          8           350         165    3693          11.5    70
# 2   18          8           318         150    3436          11.0    70
# 3   16          8           304         150    3433          12.0    70
# 4   17          8           302         140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
Auto = Auto.set_index('name') # set the index to be the car name, assuming unique names

# %%
Auto.head()
# Out:
#                            mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu   18          8           307         130    3504
# buick skylark 320           15          8           350         165    3693
# plymouth satellite          18          8           318         150    3436
# amc rebel sst               16          8           304         150    3433
# ford torino                 17          8           302         140    3449
#
#                            acceleration  year  origin
# name
# chevrolet chevelle malibu          12.0    70       1
# buick skylark 320                  11.5    70       1
# plymouth satellite                 11.0    70       1
# amc rebel sst                      12.0    70       1
# ford torino                        10.5    70       1

# %% [markdown]
# ## (a) Quantitative vs Qualitative predictors

# %% [markdown]
# The quantitative predictors are: mpg, cylinders, displacement, horsepower, weight, acceleration, year. The qualitative predictors are the origin and the name.

# %% [markdown]
# ## (b) Ranges of Quantitative predictors

# %%
Auto.apply(lambda x: x.max()-x.min() )
# Out:
# mpg               37.6
# cylinders          5.0
# displacement     387.0
# horsepower       184.0
# weight          3527.0
# acceleration      16.8
# year              12.0
# origin             2.0
# dtype: float64

# %% [markdown]
# ## (c) Mean and Std of Quantitative Predictors

# %%
Auto.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  397.000000  397.000000    397.000000  392.000000   397.000000
# mean    23.515869    5.458438    193.532746  104.469388  2970.261965
# std      7.825804    1.701577    104.379583   38.491160   847.904119
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.000000   75.000000  2223.000000
# 50%     23.000000    4.000000    146.000000   93.500000  2800.000000
# 75%     29.000000    8.000000    262.000000  126.000000  3609.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration        year      origin
# count    397.000000  397.000000  397.000000
# mean      15.555668   75.994962    1.574307
# std        2.749995    3.690005    0.802549
# min        8.000000   70.000000    1.000000
# 25%       13.800000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %%
reducedAuto = pd.concat([Auto[0:9], Auto[84:]])

# %%
reducedAuto.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  322.000000  322.000000    322.000000  318.000000   322.000000
# mean    24.446584    5.366460    186.770186  100.915094  2931.372671
# std      7.897147    1.652674     99.606562   35.846268   810.712477
# min     11.000000    3.000000     68.000000   46.000000  1649.000000
# 25%     18.000000    4.000000     98.500000   75.000000  2211.250000
# 50%     23.950000    4.000000    144.500000   90.000000  2792.500000
# 75%     30.650000    6.000000    250.000000  115.000000  3494.250000
# max     46.600000    8.000000    455.000000  230.000000  4997.000000
#
#        acceleration        year      origin
# count    322.000000  322.000000  322.000000
# mean      15.725466   77.136646    1.602484
# std        2.676686    3.119623    0.818627
# min        8.500000   70.000000    1.000000
# 25%       14.000000   75.000000    1.000000
# 50%       15.550000   77.000000    1.000000
# ...

# %% [markdown]
# ## (d) Investigate predictors graphically

# %%
from pandas.tools.plotting import scatter_matrix

# %%
scatter_matrix(Auto,figsize=(10,12));

# %% [markdown]
# **If we were to construct a model to predict mpgs some of the important predictors to consider would be  displacement, horsepower and wieght. Each plot of the mpg vs. predictor for these three predictors is a nonlinear decreasing trend. To a lesser degree we could also look at the number of cylinders and the acceleration as each of these has a weak trend with mpgs.**
